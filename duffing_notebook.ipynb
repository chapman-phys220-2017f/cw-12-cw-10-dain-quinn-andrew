# %%
import duffing
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Specification of Duffing Oscillator

# %% [markdown]
#  Consider a ball of mass $m$ with horizontal coordinate $x$ rolling in a double-well potential $V(x) = x^4/4 - x^2/2$. (This is sometimes called the "sombrero" potential. Plot it to see why, for $x\in[-1.5,1.5]$.) This potential produces a force $f_{\text{hat}}(x) = -V'(x) = -x^3 + x$ on the rolling ball. Suppose the ball also has slight friction, so experiences a drag force $f_{\text{drag}}(\dot{x}) = -\nu \dot{x}$. With these forces we thus expect the ball to roll down the sides of the sombrero potential and settle in one of the two stable wells. However, this is boring, so instead we are going to shake the hat back and force periodically with a driving force $f_{\text{drive}}(t) = F\cos(\omega t)$. For small driving forces $F$, this should simply jiggle the ball back and forth at the bottom of one of the stable wells. Our task will be to explore what happens for larger driving forces $F$.

# %% [markdown]
# Note that according to Newton's second law, the ball must satisfy the equation of motion: $$m\ddot{x} = f_{\text{hat}}(x) + f_{\text{drag}}(\dot{x}) + f_{\text{drive}}(t) = x - x^3 - \nu \dot{x} +      F\cos(\omega t)$$
# This system is known as a periodically driven nonlinear "Duffing oscillator," and can be split into a set of two coupled first-order ODEs:
# $$\dot{x}(t) = y(t)$$
# $$m\dot{y}(t) = -\nu y(t) + x(t) - x^3(t) + F\cos(\omega t)$$

# %% [markdown]
# ## Assignment

# %% [markdown]
# ##### The task is to solve these equations numerically, for $m=1$, $\nu = 0.25$, and $\omega = 1$. Use a time-step size of $\Delta t = 0.001$ with the 4th-order Runge-Kutta integration method to keep sufficient numerical precision, and implement your code in a python file ```sombrero.py``` with suitable test functions in ```test_sombrero.py```.

# %%
def potential(x):
    return x**4/4-x**2/2
t = np.linspace(-1.7,1.7,100)
plt.plot(t,potential(t))
plt.xlabel("position")
plt.ylabel("potential")
plt.title("'Sombrero' potential")
plt.show()

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ##### For $F = 0.18$, plot $x(t)$ for $t\in[0,2\pi\, 50]$, with $x(0) = -0.9$ and $y(0) = 0$.

# %%
t,x,y = duffing.rk(a=0, b=50, x0=-0.9, y0=0, nu=0.25, F=0.18)

# %%
duffing.plot(x,t,'Motion of the oscillator')

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,'Phase space of this duffing oscillator')

# %% [markdown]
# ### Poincare Section

# %% [markdown]
# #### Plotting a scatter plot of the points $(x(t),y(t))$, with specific $t = n 2\pi$ for $n = 0,1,\ldots,50$.

# %%
duffing.scatter_plot(x,y,50,"Poincare section of this duffing oscillator")

# %% [markdown]
# ## Problem 2

# %% [markdown]
# #### Plotting results for $x(0) = 0.9$ and $y(0) = 0$.

# %%
What is different?  Interpret your results.

# %%
t,x,y = duffing.rk(a=0, b=50, x0=0.9, y0=0, nu=0.25, F=0.18)

# %%
duffing.plot(x,t,"Motion of the oscillator")

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,"Phase space of this duffing oscillator")

# %% [markdown]
# ### Poincare Section

# %% [markdown]
# #### Plotting a scatter plot of the points $(x(t),y(t))$, with specific $t = n 2\pi$ for $n = 0,1,\ldots,50$.

# %%
duffing.scatter_plot(x,y,50,"Poincare section of this duffing oscillator")

# %% [markdown]
# ## Problem 3

# %% [markdown]
# #### Repeat the first question, but for $F = 0.25$, $x(0) = 0.2$, and $y(0) = 0.1$.  What is different?  Plot what happens if you change to $x(0) = 0.201$.

# %%
t,x,y = duffing.rk(a=0, b=50, x0=0.2, y0=0.1, nu=0.25, F=0.25)

# %%
duffing.plot(x,t,"Motion of the oscillator")

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,"Phase space diagram of this duffing oscillator")

# %% [markdown]
# ### Poincare Section

# %%
duffing.scatter_plot(x,y,50,"Poincare section of this duffing oscillator")

# %% [markdown]
# ### Plotting Change from $x(0) = 0.201$.

# %%
t,x,y = duffing.rk(a=0, b=50, x0=0.201, y0=0.1, nu=0.25, F=0.25)

# %%
duffing.plot(x,t,"Motion of the oscillator")

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,"Phase space of this duffing Oscillator")

# %% [markdown]
# ### Poincare Section

# %%
duffing.scatter_plot(x,y,50,"Poincare section of this duffing oscillator")

# %% [markdown]
# ### Problem 4

# %% [markdown]
# ##### Repeat the first question, but for $F = 0.4$, $x(0) = 0$, and $y(0) = 0$.  What is different now?  What happens when you tweak the initial conditions?  How do you interpret this physically?

# %%
t,x,y = duffing.rk(a=0, b=50, x0=0, y0=0, nu=0.25, F=0.4)

# %%
duffing.plot(x,t,"Motion of the oscillator")

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,"Phase space of this duffing oscillator")

# %% [markdown]
# ### Poincare Section

# %%
duffing.scatter_plot(x,y,50,"Poincare section of this duffing oscillator")

# %% [markdown]
# ### Changing Initial Conditions

# %%
t,x,y = duffing.rk(a=0, b=50, x0=0.03, y0=0.22, nu=0.25, F=0.4)

# %%
duffing.plot(x,t,"Motion of the oscillator")

# %% [markdown]
# ### Parametrized Curve

# %% [markdown]
# #### Plotting the parametric curve $(x(t),y(t))$ in the x-y plane for the same time range.

# %%
duffing.parametric_plot(x,y,"Phase space of this duffing Oscillator")

# %% [markdown]
# ### Poincare Section

# %%
duffing.scatter_plot(x,y,50,"Poincare section")

# %% [markdown]
# ### Poincare Section

# %% [markdown]
# #### Extending the time range to $t\in[0,2\pi\, 1000]$.  What is the structure of the Poincare section?

# %%
t,x,y = duffing.rk(a=0, b=1000, x0=0, y0=0, nu=0.25, F=0.4)

# %%
duffing.scatter_plot(x,y,1000,"Poincare section")
